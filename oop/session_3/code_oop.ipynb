# %%
class Rectangle:
    def __init__(self, length)->None:
        self.__length=length

# %%
r1=Rectangle(10)
r1.Rectangle__iength 
print(r1.__dict__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 r1=Rectangle(10)
# ----> 2 r1.Rectangle__iength
#       3 print(r1.__dict__)
#
# AttributeError: 'Rectangle' object has no attribute 'Rectangle__iength'

# %%
add(int)
add(int,int)

# %%
class Calc:
    def add(self,a):
        return a 
    def add(self,a,b=0):
        return a+b

# %%
c1=Calc()
c1.add(2)
# Out:
# 2
