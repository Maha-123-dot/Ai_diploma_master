# %%
class Student:
    def __init__(self, name: str = "test", age=10) -> None:
        self.name = name
        self.age = age

    def std_inf(self):
        print(self.name, self.age)
    def std_inf(self):
        print(self.name,self.age)
# Out:
#   Cell In[7], line 2
#     def_init_(self, name : str ="test",age=10)->str:
#                          ^
# SyntaxError: invalid syntax

# %%
class student :
    def __init__(self, name:str="test", age=20)->str:
            self.name = name
            self.age = age
    def std_info(self):
        print(self.name,self.age)
