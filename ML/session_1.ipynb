# %%
import numpy as np     
from sklearn.metrics import mean_squared_error,r2_score  
from sklearn.linear_model import LinearRegression, Ridge, Lasso
import matplotlib .pyplot as plt

# %%
x = np.array([[1],[2],[3],[4]])
y =np.array([2,4,6,8])

# %%
#=======================
#linear regression 
#=======================
linear_reg=LinearRegression()
linear_reg.fit(x,y)
y_pred=linear_reg.predict(x)    
#=========================
#Ridge Regression with small alpha 
ridge = Ridge(alpha=1.0)
ridge.fit(x,y)
y_pred=ridge.predict(x) 
#=========================
#Lasso Regression with small alpha      
lasso =Lasso(alpha=0.1) 
lasso.fit(x,y)
y_pred=lasso.predict(x)
#======================
print("LinearRegression")
print("Mean squared error: %.2f" % mean_squared_error(y, y_pred))   
print("Coefficient of determination: %.2f" % r2_score(y, y_pred)) 
print("b")
# Out:
# LinearRegression
# Mean squared error: 0.01
# Coefficient of determination: 1.00

# %%
#Ridge Regression
plt.figure(figsize=(12,4))
plt.subplot(1, 3,2 )
plt.scatter(x, y, color='blue',label="Actual data")
plt.plot(x, y_pred, color='blue', linewidth=3)
plt.title("Ridge Regression with small alpha")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()

# %%
plt.subplot(1, 3,3 )

# %%
plt.scatter(x,y, color="blue",label="Actual data")
plt.plot(x,y_pred_lin, color = "red",label ="Linear Regression")
plt.plot(x,y_pred_ridge, color = "green",linestyle="--",label ="Ridge Regression")
plt.plot(x,y_pred_lasso, color = "purple",linestyle="--",label ="Lasso Regression")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 plt.scatter(x,y, color="blue",label="Actual data")
# ----> 2 plt.plot(x,y_pred_lin, color = "red",label ="Linear Regression")
#       3 plt.plot(x,y_pred_ridge, color = "green",linestyle="--",label ="Ridge Regression")
#       4 plt.plot(x,y_pred_lasso, color = "purple",linestyle="--",label ="Lasso Regression")
#       5
#
# NameError: name 'y_pred_lin' is not defined

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)

y_pred_ridge = ridge.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 from sklearn.linear_model import Ridge
#       2
#       3 ridge = Ridge(alpha=1.0)
# ----> 4 ridge.fit(X_train, y_train)
#       5
#       6 y_pred_ridge = ridge.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
linear_model = linear_reg
ridge_model = ridge
lasso_model = lasso

y_pred = linear_model.predict(x)

if not hasattr(ridge_model, "n_features_in_"):
    ridge_model.fit(x, y)
y_pred_ridge = ridge_model.predict(x)

y_pred_lasso = lasso_model.predict(x)

# %%
plt.scatter(x, y, color="blue", label="Actual data")
plt.plot(x, y_pred, color="red", label="Linear Regression")
plt.plot(x, y_pred_ridge, color="green", linestyle="--", label="Ridge Regression")
plt.plot(x, y_pred_lasso, color="purple", linestyle="--", label="Lasso Regression")
plt.title("Comparison of Linear, Ridge, and Lasso Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
