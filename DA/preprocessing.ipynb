# %%
import pandas as pd

df = pd.read_csv("Titanic.csv")

print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(["PassengerId", "Name", "Ticket"], axis=1, inplace=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]>

# %%
Drop_COLUMS=["PassengerId", "Name", "Ticket"]

# %%
def drop_cols(df: pd.DataFrame, cols: list[str]) -> pd.DataFrame:
    return df.drop(columns=cols)

df = drop_cols(df,Drop_COLUMS)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
#check data type

# %%
class Student:
    def __init__(self, name) -> None:
        self._name = name

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, value):
        self._name = value

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex             str
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Cabin           str
# Embarked        str
# dtype: object

# %%
dtypes = df.dtypes
n_uniq = df.nunique()
n_uniq
dtypes = df.dtypes
n_uniq = df.nunique()
n_uniq
pd.DataFrame({"Dtypes": dtypes, "Num_unique": n_uniq})
# Out:
#            Dtypes  Num_unique
# Survived    int64           2
# Pclass      int64           3
# Sex           str           2
# Age       float64          88
# SibSp       int64           7
# Parch       int64           7
# Fare      float64         248
# Cabin         str         147
# Embarked      str           3

# %%
null = df.isnull().sum()
null
null
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
cols=['pclass','survived','sibsp','sex','parch','Embarked']
cols = ['Pclass', 'Survived', 'SibSp', 'Sex', 'Parch', 'Embarked']
df[cols] = df[cols].astype('category')
pd.DataFrame(df.dtypes).T
# Out:
#    Survived    Pclass       Sex      Age     SibSp     Parch     Fare Cabin  \
# 0  category  category  category  float64  category  category  float64   str
#
#    Embarked
# 0  category

# %%
df.shape[0]
# Out:
# 891

# %%
null=df.isnull().sum()
ratio=null/df.shape[0]
null
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df=df.dropna(subset=['Embarked'])

# %%
df=df.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df=df.drop()
#
# File c:\python\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File c:\python\Lib\site-packages\pandas\core\generic.py:4624, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4620             axes = {"index": index}
#    4621             if self.ndim == 2:
#    4622                 axes["columns"] = columns
#    4623         else:
# -> 4624             raise ValueError(
#    4625                 "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4626             )
#    4627
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'

# %%
mean = df["Age"].mean()
mean

# %%
df.describe()
# Out:
#               Age        Fare
# count  712.000000  889.000000
# mean    29.642093   32.096681
# std     14.492933   49.697504
# min      0.420000    0.000000
# 25%     20.000000    7.895800
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
num_cols=df.select_dtypes("number").columns
num_cols
# Out:
# Index(['Age', 'Fare'], dtype='str')

# %%
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_fence = Q1 - 1.5 * IQR
    upper_fence = Q3 + 1.5 * IQR

    print(f"{col}: lower={lower_fence}, upper={upper_fence}")
    lower_outliers = df[df[col] < lower_fence][col].values
    upper_outliers = df[df[col] > upper_fence][col].values
    print(upper_outliers)
# Out:
# Age: lower=-7.0, upper=65.0
# [66.  71.  70.5 71.  80.  70.  70.  74. ]
# Fare: lower=-26.7605, upper=65.6563
# [ 71.2833 263.     146.5208  82.1708  76.7292  83.475   73.5    263.
#   77.2875 247.5208  73.5     77.2875  79.2     66.6     69.55    69.55
#  146.5208  69.55   113.275   76.2917  90.      83.475   90.      79.2
#   86.5    512.3292  79.65   153.4625 135.6333  77.9583  78.85    91.0792
#  151.55   247.5208 151.55   110.8833 108.9     83.1583 262.375  164.8667
#  134.5     69.55   135.6333 153.4625 133.65    66.6    134.5    263.
#   75.25    69.3    135.6333  82.1708 211.5    227.525   73.5    120.
#  113.275   90.     120.     263.      81.8583  89.1042  91.0792  90.
#   78.2667 151.55    86.5    108.9     93.5    221.7792 106.425   71.
#  106.425  110.8833 227.525   79.65   110.8833  79.65    79.2     78.2667
#  153.4625  77.9583  69.3     76.7292  73.5    113.275  133.65    73.5
#  512.3292  76.7292 211.3375 110.8833 227.525  151.55   227.525  211.3375
#  512.3292  78.85   262.375   71.      86.5    120.      77.9583 211.3375
#   79.2     69.55   120.      93.5     83.1583  69.55    89.1042 164.8667
#   69.55    83.1583]

# %%
df.describe()
# Out:
#               Age        Fare
# count  712.000000  889.000000
# mean    29.642093   32.096681
# std     14.492933   49.697504
# min      0.420000    0.000000
# 25%     20.000000    7.895800
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.1-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in c:\python\lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\python\lib\site-packages (from matplotlib) (12.3.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.1-cp312-cp312-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.3 MB 1.7 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.3 MB 1.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.3 MB 1.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.3 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.3 MB 1.5 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.3 MB 1.6 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.3 MB 1.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.4/9.3 MB 1.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.6/9.3 MB 1.3 MB/s eta 0:00:06
#    ------------ --------------------------- 2.9/9.3 MB 1.4 MB/s eta 0:00:05
#    -------------- ------------------------- 3.4/9.3 MB 1.4 MB/s eta 0:00:05
#    -------------- ------------------------- 3.4/9.3 MB 1.4 MB/s eta 0:00:05
#    --------------- ------------------------ 3.7/9.3 MB 1.3 MB/s eta 0:00:05
#    ---------------- ----------------------- 3.9/9.3 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.3 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.3 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.3 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 4.5/9.3 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.5/9.3 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.5/9.3 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.5/9.3 MB 1.2 MB/s eta 0:00:05
#    -------------------- ------------------- 4.7/9.3 MB 997.2 kB/s eta 0:00:05
#    -------------------- ------------------- 4.7/9.3 MB 997.2 kB/s eta 0:00:05
#    -------------------- ------------------- 4.7/9.3 MB 997.2 kB/s eta 0:00:05
#    --------------------- ------------------ 5.0/9.3 MB 920.7 kB/s eta 0:00:05
#    --------------------- ------------------ 5.0/9.3 MB 920.7 kB/s eta 0:00:05
#    --------------------- ------------------ 5.0/9.3 MB 920.7 kB/s eta 0:00:05
#    --------------------- ------------------ 5.0/9.3 MB 920.7 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.2/9.3 MB 841.1 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.2/9.3 MB 841.1 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.2/9.3 MB 841.1 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.2/9.3 MB 841.1 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.2/9.3 MB 841.1 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.2/9.3 MB 841.1 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.2/9.3 MB 841.1 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.2/9.3 MB 841.1 kB/s eta 0:00:05
#    ----------------------- ---------------- 5.5/9.3 MB 682.0 kB/s eta 0:00:06
#    ----------------------- ---------------- 5.5/9.3 MB 682.0 kB/s eta 0:00:06
#    ----------------------- ---------------- 5.5/9.3 MB 682.0 kB/s eta 0:00:06
#    ----------------------- ---------------- 5.5/9.3 MB 682.0 kB/s eta 0:00:06
#    ----------------------- ---------------- 5.5/9.3 MB 682.0 kB/s eta 0:00:06
#    ----------------------- ---------------- 5.5/9.3 MB 682.0 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.3 MB 619.2 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.3 MB 619.2 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.3 MB 619.2 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.3 MB 619.2 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.3 MB 619.2 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.3 MB 619.2 kB/s eta 0:00:06
#    ------------------------- -------------- 6.0/9.3 MB 572.3 kB/s eta 0:00:06
#    ------------------------- -------------- 6.0/9.3 MB 572.3 kB/s eta 0:00:06
#    ------------------------- -------------- 6.0/9.3 MB 572.3 kB/s eta 0:00:06
#    ------------------------- -------------- 6.0/9.3 MB 572.3 kB/s eta 0:00:06
#    ------------------------- -------------- 6.0/9.3 MB 572.3 kB/s eta 0:00:06
#    ------------------------- -------------- 6.0/9.3 MB 572.3 kB/s eta 0:00:06
#    -------------------------- ------------- 6.3/9.3 MB 534.5 kB/s eta 0:00:06
#    -------------------------- ------------- 6.3/9.3 MB 534.5 kB/s eta 0:00:06
#    -------------------------- ------------- 6.3/9.3 MB 534.5 kB/s eta 0:00:06
#    -------------------------- ------------- 6.3/9.3 MB 534.5 kB/s eta 0:00:06
#    ---------------------------- ----------- 6.6/9.3 MB 516.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 6.6/9.3 MB 516.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 6.6/9.3 MB 516.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 6.6/9.3 MB 516.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 6.6/9.3 MB 516.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 6.6/9.3 MB 516.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 6.6/9.3 MB 516.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 6.6/9.3 MB 516.2 kB/s eta 0:00:06
#    ----------------------------- ---------- 6.8/9.3 MB 476.1 kB/s eta 0:00:06
#    ----------------------------- ---------- 6.8/9.3 MB 476.1 kB/s eta 0:00:06
#    ----------------------------- ---------- 6.8/9.3 MB 476.1 kB/s eta 0:00:06
#    ----------------------------- ---------- 6.8/9.3 MB 476.1 kB/s eta 0:00:06
#    ----------------------------- ---------- 6.8/9.3 MB 476.1 kB/s eta 0:00:06
#    ----------------------------- ---------- 6.8/9.3 MB 476.1 kB/s eta 0:00:06
#    ----------------------------- ---------- 6.8/9.3 MB 476.1 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------ --------- 7.1/9.3 MB 446.9 kB/s eta 0:00:06
#    ------------------------------- -------- 7.3/9.3 MB 400.2 kB/s eta 0:00:05
#    ------------------------------- -------- 7.3/9.3 MB 400.2 kB/s eta 0:00:05
#    ------------------------------- -------- 7.3/9.3 MB 400.2 kB/s eta 0:00:05
#    ------------------------------- -------- 7.3/9.3 MB 400.2 kB/s eta 0:00:05
#    ------------------------------- -------- 7.3/9.3 MB 400.2 kB/s eta 0:00:05
#    ------------------------------- -------- 7.3/9.3 MB 400.2 kB/s eta 0:00:05
#    ------------------------------- -------- 7.3/9.3 MB 400.2 kB/s eta 0:00:05
#    ------------------------------- -------- 7.3/9.3 MB 400.2 kB/s eta 0:00:05
#    -------------------------------- ------- 7.6/9.3 MB 376.7 kB/s eta 0:00:05
#    -------------------------------- ------- 7.6/9.3 MB 376.7 kB/s eta 0:00:05
#    -------------------------------- ------- 7.6/9.3 MB 376.7 kB/s eta 0:00:05
#    -------------------------------- ------- 7.6/9.3 MB 376.7 kB/s eta 0:00:05
#    --------------------------------- ------ 7.9/9.3 MB 373.1 kB/s eta 0:00:04
#    --------------------------------- ------ 7.9/9.3 MB 373.1 kB/s eta 0:00:04
#    --------------------------------- ------ 7.9/9.3 MB 373.1 kB/s eta 0:00:04
#    ---------------------------------- ----- 8.1/9.3 MB 373.9 kB/s eta 0:00:04
#    ---------------------------------- ----- 8.1/9.3 MB 373.9 kB/s eta 0:00:04
#    ---------------------------------- ----- 8.1/9.3 MB 373.9 kB/s eta 0:00:04
#    ----------------------------------- ---- 8.4/9.3 MB 376.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.4/9.3 MB 376.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.4/9.3 MB 376.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.4/9.3 MB 376.6 kB/s eta 0:00:03
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 376.0 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.3 MB 351.1 kB/s eta 0:00:02
#    ---------------------------------------  9.2/9.3 MB 331.5 kB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 331.5 kB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 331.5 kB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 331.5 kB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 331.5 kB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 323.4 kB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    -------- ------------------------------- 0.5/2.3 MB 119.0 kB/s eta 0:00:16
#    ------------- -------------------------- 0.8/2.3 MB 96.4 kB/s eta 0:00:17
#    ------------- -------------------------- 0.8/2.3 MB 96.4 kB/s eta 0:00:17
#    ------------- -------------------------- 0.8/2.3 MB 96.4 kB/s eta 0:00:17
#    ------------- -------------------------- 0.8/2.3 MB 96.4 kB/s eta 0:00:17
#    ------------- -------------------------- 0.8/2.3 MB 96.4 kB/s eta 0:00:17
#    ----------------- ---------------------- 1.0/2.3 MB 119.0 kB/s eta 0:00:11
#    ----------------- ---------------------- 1.0/2.3 MB 119.0 kB/s eta 0:00:11
#    ----------------- ---------------------- 1.0/2.3 MB 119.0 kB/s eta 0:00:11
#    ----------------- ---------------------- 1.0/2.3 MB 119.0 kB/s eta 0:00:11
#    ----------------- ---------------------- 1.0/2.3 MB 119.0 kB/s eta 0:00:11
#    ----------------- ---------------------- 1.0/2.3 MB 119.0 kB/s eta 0:00:11
#    ---------------------- ----------------- 1.3/2.3 MB 136.4 kB/s eta 0:00:08
#    ---------------------- ----------------- 1.3/2.3 MB 136.4 kB/s eta 0:00:08
#    ---------------------- ----------------- 1.3/2.3 MB 136.4 kB/s eta 0:00:08
#    ---------------------- ----------------- 1.3/2.3 MB 136.4 kB/s eta 0:00:08
#    ---------------------- ----------------- 1.3/2.3 MB 136.4 kB/s eta 0:00:08
#    ---------------------- ----------------- 1.3/2.3 MB 136.4 kB/s eta 0:00:08
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 145.9 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 129.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 2.1/2.3 MB 127.2 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.3 MB 127.2 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.3 MB 127.2 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.3 MB 127.2 kB/s eta 0:00:02
#    ---------------------------------------- 2.3/2.3 MB 136.6 kB/s eta 0:00:00
# Downloading kiwisolver-1.5.1-cp312-cp312-win_amd64.whl (70 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.1 matplotlib-3.11.1 pyparsing-3.3.2
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\python\lib\site-packages (from seaborn) (2.5.2)
# Requirement already satisfied: pandas>=1.2 in c:\python\lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\python\lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\python\lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
num_col = ["Age", "Fare"]
print(num_col)
plt.figure(figsize=(8, 1))
for i, col in enumerate(num_col):
    plt.subplot(1, 2, i + 1)
    sns.boxplot(x=df[col], orient="h")
    plt.title(f"{col} Boxplot")
# Out:
# ['Age', 'Fare']

# %%
num_col = df.select_dtypes('number').columns

for col in num_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_fence = Q1 - 1.5 * IQR
    upper_fence = Q3 + 1.5 * IQR

    lower_outliers = df[df[col] < lower_fence][col].values
    upper_outliers = df[df[col] > upper_fence][col].values

    df[col] = df[col].clip(lower=lower_fence, upper=upper_fence)

    print(lower_outliers)
    print(upper_outliers)
# Out:
# []
# [66.  71.  70.5 71.  80.  70.  70.  74. ]
# []
# [ 71.2833 263.     146.5208  82.1708  76.7292  83.475   73.5    263.
#   77.2875 247.5208  73.5     77.2875  79.2     66.6     69.55    69.55
#  146.5208  69.55   113.275   76.2917  90.      83.475   90.      79.2
#   86.5    512.3292  79.65   153.4625 135.6333  77.9583  78.85    91.0792
#  151.55   247.5208 151.55   110.8833 108.9     83.1583 262.375  164.8667
#  134.5     69.55   135.6333 153.4625 133.65    66.6    134.5    263.
#   75.25    69.3    135.6333  82.1708 211.5    227.525   73.5    120.
#  113.275   90.     120.     263.      81.8583  89.1042  91.0792  90.
#   78.2667 151.55    86.5    108.9     93.5    221.7792 106.425   71.
#  106.425  110.8833 227.525   79.65   110.8833  79.65    79.2     78.2667
#  153.4625  77.9583  69.3     76.7292  73.5    113.275  133.65    73.5
#  512.3292  76.7292 211.3375 110.8833 227.525  151.55   227.525  211.3375
#  512.3292  78.85   262.375   71.      86.5    120.      77.9583 211.3375
#   79.2     69.55   120.      93.5     83.1583  69.55    89.1042 164.8667
#   69.55    83.1583]

# %%
num_col = ["Age", "Fare"]
for col in num_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_fence = Q1 - 1.5*IQR
    upper_fence = Q3 + 1.5 *IQR
   
    lower_outliers = df[   df[col] <      lower_fence]    [col].values
    upper_outliers = df[   df[col] >      upper_fence]    [col].values
   
 
    df[col].replace(lower_outliers, lower_fence)
    df[col].replace(upper_outliers, upper_fence)

# %%
def plot_num_bloxplot(df):
    num_col=['Age','fare']

# %%
def remove_duplicated_records(df, subset_cols=None, keep_strategy="first"):
    return df.drop_duplicates(
        subset=subset_cols,
        keep=keep_strategy
    ).reset_index(drop=True)

# %%
remove_duplicated_records(df)
# Out:
#     Survived Pclass     Sex   Age SibSp Parch     Fare Cabin Embarked
# 0          0      3    male  22.0     1     0   7.2500   NaN        S
# 1          1      1  female  38.0     1     0  65.6563   C85        C
# 2          1      3  female  26.0     0     0   7.9250   NaN        S
# 3          1      1  female  35.0     1     0  53.1000  C123        S
# 4          0      3    male  35.0     0     0   8.0500   NaN        S
# ..       ...    ...     ...   ...   ...   ...      ...   ...      ...
# 774        0      3  female  39.0     0     5  29.1250   NaN        Q
# 775        1      1  female  19.0     0     0  30.0000   B42        S
# 776        0      3  female   NaN     1     2  23.4500   NaN        S
# 777        1      1    male  26.0     0     0  30.0000  C148        C
# 778        0      3    male  32.0     0     0   7.7500   NaN        Q
#
# [779 rows x 9 columns]

# %%
cat_cols = df.select_dtypes(include=["object", "category"]).columns

fig, axes = plt.subplots(
    1, len(cat_cols),
    figsize=(5 * len(cat_cols), 4),
    squeeze=False
)

for ax, col in zip(axes[0], cat_cols):
    sns.countplot(data=df, x=col, ax=ax)
    ax.set_title(f"{col} Distribution")
    ax.tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()
plt
# Out:
# C:\Users\SHARKS\AppData\Local\Temp\ipykernel_27308\3241130067.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=["object", "category"]).columns
# <module 'matplotlib.pyplot' from 'c:\\python\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
cat_cols = df.select_dtypes("category").columns

plt.figure(figsize=(14,4))

for i, col in enumerate(cat_cols):
    plt.subplot(2,3,i+1)
    unique=df[col].value_counts()
    sns.countplot(x=col, data=df)
    plt.title(f"{col} countPlot_dist")

# %%
cat_cols
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'], dtype='str')

# %%
unique=df[col].value_counts()
count=unique.values
category=
count
# Out:
# array([644, 168,  77])

# %%
cat_cols

plt.figure(figsize=(9,4))

for i, col in enumerate(cat_cols):
    plt.subplot(2,3,i+1)
    unique = df[col].value_counts()
    count = unique.values
    categories = unique.index
    plt.pie(count, labels=categories, startangle=140, autopct='%1.1f%%')
    plt.title(f"{col} Pie plot")

plt.subplots_adjust(hspace=0.8, wspace=0.3)
plt.show()

# %%
corr_1=df.corr(numeric_only=True)
corr_1
# Out:
#            Age      Fare
# Age   1.000000  0.147042
# Fare  0.147042  1.000000

# %%
plt.Figure

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:
7 kB/s eta 0:00:07
#    ----------------------------------- ---- 32.8/36.7 MB 751.9 kB/s eta 0:00:06
#    ------------------------------------ --- 33.0/36.7 MB 756.9 kB/s eta 0:00:05
#    ------------------------------------ --- 33.6/36.7 MB 766.7 kB/s eta 0:00:05
#    ------------------------------------ --- 33.8/36.7 MB 771.9 kB/s eta 0:00:04
#    ------------------------------------- -- 34.3/36.7 MB 782.6 kB/s eta 0:00:03
#    -------------------------------------- - 34.9/36.7 MB 810.1 kB/s eta 0:00:03
#    -------------------------------------- - 35.4/36.7 MB 821.5 kB/s eta 0:00:02
#    ---------------------------------------  35.9/36.7 MB 833.1 kB/s eta 0:00:01
#    ---------------------------------------  36.4/36.7 MB 845.9 kB/s eta 0:00:01
#    ---------------------------------------- 36.7/36.7 MB 846.7 kB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, joblib, scikit-learn
# Successfully installed joblib-1.5.3 narwhals-2.25.0 scikit-learn-1.9.0 scipy-1.18.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x[num_cols] = scaler.fit_transform(df[num_cols])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 scaler=MinMaxScaler()
# ----> 3 df[num_cols] = scaler.fit_transform(df[num_cols])
#
# NameError: name 'df' is not defined

# %%
pip install category-encoders
# Out:
# Collecting category-encoders
#   Downloading category_encoders-2.10.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\python\lib\site-packages (from category-encoders) (2.5.2)
# Requirement already satisfied: pandas>=1.0.5 in c:\python\lib\site-packages (from category-encoders) (3.0.5)
# Collecting patsy>=0.5.1 (from category-encoders)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\python\lib\site-packages (from category-encoders) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\python\lib\site-packages (from category-encoders) (1.18.1)
# Collecting statsmodels>=0.9.0 (from category-encoders)
#   Downloading statsmodels-0.15.0-cp312-cp312-win_amd64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from pandas>=1.0.5->category-encoders) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\python\lib\site-packages (from pandas>=1.0.5->category-encoders) (2026.3)
# Requirement already satisfied: joblib>=1.4.0 in c:\python\lib\site-packages (from scikit-learn>=1.6.0->category-encoders) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\python\lib\site-packages (from scikit-learn>=1.6.0->category-encoders) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\python\lib\site-packages (from scikit-learn>=1.6.0->category-encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from statsmodels>=0.9.0->category-encoders) (26.2)
# Collecting formulaic>=1.1.0 (from statsmodels>=0.9.0->category-encoders)
#   Downloading formulaic-1.2.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.1.0->statsmodels>=0.9.0->category-encoders)
#   Downloading interface_meta-2.0.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from formulaic>=1.1.0->statsmodels>=0.9.0->category-encoders) (4.16.0)
# Collecting wrapt>=1.0 (from formulaic>=1.1.0->statsmodels>=0.9.0->category-encoders)
#   Downloading wrapt-2.3.0-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\sharks\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category-encoders) (1.17.0)
# Downloading category_encoders-2.10.0-py3-none-any.whl (87 kB)
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading statsmodels-0.15.0-cp312-cp312-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.3 MB 4.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.3 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/11.3 MB 3.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.3 MB 3.9 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.3 MB 4.0 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.3 MB 3.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.3 MB 3.5 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.3 MB 3.5 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.3 MB 3.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.3 MB 3.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.3 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.3 MB 3.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 3.5 MB/s eta 0:00:00
# Downloading formulaic-1.2.2-py3-none-any.whl (118 kB)
# Downloading interface_meta-2.0.1-py3-none-any.whl (15 kB)
# Downloading wrapt-2.3.0-cp312-cp312-win_amd64.whl (81 kB)
# Installing collected packages: wrapt, patsy, interface-meta, formulaic, statsmodels, category-encoders
# Successfully installed category-encoders-2.10.0 formulaic-1.2.2 interface-meta-2.0.1 patsy-1.0.2 statsmodels-0.15.0 wrapt-2.3.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from category_encoders import OneHotEncoder
str_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()
x = df.copy()
encoder = OneHotEncoder(cols=str_cols, drop_invariant=True)
x=encoder.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 from category_encoders import OneHotEncoder
# ----> 2 str_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()
#       3 x = df.copy()
#       4 encoder = OneHotEncoder(cols=str_cols, drop_invariant=True)
#       5 x=encoder.fit_transform(x)
#
# NameError: name 'df' is not defined
