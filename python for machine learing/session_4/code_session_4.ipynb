# %%
class StudentInfo:
    name="maha"
    age=20
    def std_info(self):
        print(self)
        print(f"my name maha")

# %%
s1= StudentInfo()
s1.age=40
s1.name="Amit"
print(s1.name)
print(s1.age)
s1.std_info()
# Out:
# Amit
# 40
# my name maha

# %%
s1= StudentInfo()
print(s1)
s1.std_info()
# Out:
# ...
# my name maha
