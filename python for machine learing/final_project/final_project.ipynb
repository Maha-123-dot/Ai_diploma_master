# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print("New balance:", self.balance)

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        elif amount > 0:
            self.balance -= amount
            print("New balance:", self.balance)

    def check_balance(self):
        print("Balance:", self.balance)


account = BankAccount(100)

account.deposit(50)
account.withdraw(30)
account.check_balance()
# Out:
# New balance: 150
# New balance: 120
# Balance: 120

# %%
class Calculator:

    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b

    def multiply(self, a, b):
        return a * b

    def divide(self, a, b):
        if b == 0:
            return "Cannot divide by zero"
        return a / b


calc = Calculator()

print(calc.add(22, 33))
print(calc.subtract(22, 33))
print(calc.multiply(22, 33))
print(calc.divide(22, 33))
# Out:
# 55
# -11
# 726
# 0.6666666666666666

# %%
from abc import ABC, abstractmethod


class Animal(ABC):

    @abstractmethod
    def make_sound(self):
        pass

    def describe(self):
        print("This is an animal")


class Dog(Animal):

    def make_sound(self):
        return "Woof"


class Cat(Animal):

    def make_sound(self):
        return "Meow"


class Cow(Animal):

    def make_sound(self):
        return "Moo"


dog = Dog()
cat = Cat()
cow = Cow()

dog.describe()
print(dog.make_sound())

cat.describe()
print(cat.make_sound())

cow.describe()
print(cow.make_sound())
# Out:
# This is an animal
# Woof
# This is an animal
# Meow
# This is an animal
# Moo

# %%
class TextFileReader:

    def __init__(self, file_path):
        self.file_path = file_path
        self.content = ""

    def read_file(self):
        file = open(self.file_path, "r")
        self.content = file.read()
        file.close()

    def count_lines(self):
        return len(self.content.splitlines())

    def count_words(self):
        return len(self.content.split())

    def count_characters(self):
        return len(self.content)

    def display_content(self):
        print(self.content)


reader = TextFileReader("test.txt")

reader.read_file()

print("Lines:", reader.count_lines())
print("Words:", reader.count_words())
print("Characters:", reader.count_characters())

reader.display_content()
# Out:
# Lines: 2
# Words: 6
# Characters: 37
# Hello Maha
# Welcom to final project

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\SHARKS\Desktop\Ai_diploma_master\Ai_diploma_master\python for machine learing\final_project
# ['final_project.ipynb', 'test.txt']

# %%
def count_words(words):

    result = {}

    for word in words:
        if word in result:
            result[word] += 1
        else:
            result[word] = 1

    return result


words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]

print(count_words(words))
# Out:
# {'Welcome': 1, 'Ali': 4, 'Hi': 2, 'No': 3}

# %%
def read_txt_file(file_path):

    try:
        file = open(file_path, "r")
        content = file.read()
        file.close()
        return content

    except:
        return "Error: File not found"


class UserExtractor:

    def __init__(self, file_path):
        self.file_path = file_path
        self.usernames = {}

    def extract_usernames(self):

        content = read_txt_file(self.file_path)

        for line in content.splitlines():

            username, password = line.split(":")

            self.usernames[username] = password

        return self.usernames


user = UserExtractor("users.txt")

print(user.extract_usernames())
# Out:
# {'Maha': '1234', 'Hager': '6789', 'Ali': '4567'}
