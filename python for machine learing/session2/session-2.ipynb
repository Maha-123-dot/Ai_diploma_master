# %%
list_one =[1,2,3,4,"Depi","Machine learning"]
print(list)
# Out:
# <class 'list'>

# %%
list_1 = ["Depi", "ml"]
list_1.remove("Depi")
print(list_1)
# Out:
# ['ml']

# %%
print("maha")
# Out:
# maha

# %%
list=["maha","kaled"]
list.pop()
# Out:
# 'kaled'

# %%
#name= input("enter name")
#age=input("enter age")
name="maha"
age=20
print(f"my name is {name},and my age is {age}")
# Out:
# my name is maha,and my age is 20

# %%
my_list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]
item = input("Enter item to remove: ")
if item in my_list:
    my_list.remove(item)
    print("Updated list:", my_list)
else:
    print("Item not found!")
# Out:
# Item not found!

# %%
list_5=[3,4,6,7]
list_5.sort()
print(list_5)
list_5.clear()
print(list_5)
# Out:
# [3, 4, 6, 7]
# []

# %%
tuple_1=(1,2,3)
list_1=list(tuple_1)
list_1[0]="depi"
print(list_1)
# Out:
# ['depi', 2, 3]

# %%
x={1,2,3}
type(x)
# Out:
# set

# %%
x2={1:"maha"}
type(x2)
# Out:
# dict

# %%
A={1,2,3}
B={4,5}
print(A|B)
# Out:
# {1, 2, 3, 4, 5}

# %%
dict_1={"key1":12.4,"key2":5}
dict_1["key1"]="maha"
print(dict_1["key2"])
print(dict_1["key1"])
# Out:
# 5
# maha

# %%
value_1=[('a',1),('b',2)]
dict_2=dict(value_1)
print(type(dict_2))
# Out:
# <class 'dict'>

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
4==4
# Out:
# True

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
print("Addition =", num1 + num2)
print("Subtraction =", num1 - num2)
print("Multiplication =", num1 * num2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 num1 = int(input("Enter the first number: "))
#       2 num2 = int(input("Enter the second number: "))
#       3 print("Addition =", num1 + num2)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a=200
b=33
if b > a :
    print("b is biger")
else:
    print("b is not biger")
# Out:
# b is not biger

# %%
x=5
y=10
if x>0 and y>0:
    print("both greater thin zero")
# Out:
# both greater thin zero

# %%
degree = int(input("Enter degree: "))
if degree >= 90:
    print("A")
elif degree >= 80:
    print("B")
elif degree >= 70:
    print("C")
elif degree >= 60:
    print("D")
else:
    print("F")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 degree = int(input("Enter degree: "))
#       2 if degree >= 90:
#       3     print("A")
#       4 elif degree >= 80:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
if 0<=score<=100
